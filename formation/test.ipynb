# %%
import allotment_matching as am

# %%
init_pts = am.generate_source_pts(1000, [0, 0], [1, 1])
final_pts = am.generate_source_pts(1000, [0, 0], [1, 1])
test = am.min_largest(init_pts, final_pts)
# Out:
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (linux64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 600 rows, 90000 columns and 180000 nonzeros
# Model fingerprint: 0x3243f969
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-03, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.13s
# Presolved: 599 rows, 90000 columns, 179700 nonzeros
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 8.970e+04
#  Factor NZ  : 1.797e+05 (roughly 40 MBytes of memory)
#  Factor Ops : 7.182e+07 (less than 1 second per iteration)
#  Threads    : 4
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
# ...

# %%
for s in range(300):
    for t in range(300):
        if abs(am.pl.value(test[s][t]) - 1) <= 0.001:
            print(s, t, am.pl.value(test[s][t]))
# Out:
# 0 183 1.0
# 1 82 1.0
# 2 126 1.0
# 3 122 1.0
# 4 121 1.0
# 5 94 1.0
# 6 158 1.0
# 7 66 1.0
# 8 9 1.0
# 9 28 1.0
# 10 276 1.0
# 11 166 1.0
# 12 257 1.0
# 13 234 1.0
# 14 75 1.0
# 15 68 1.0
# 16 232 1.0
# 17 188 1.0
# 18 79 1.0
# 19 56 1.0
# 20 226 1.0
# 21 29 1.0
# 22 268 1.0
# 23 186 1.0
# 24 88 1.0
# 25 152 1.0
# 26 206 1.0
# 27 184 1.0
# 28 251 1.0
# 29 7 1.0
# 30 169 1.0
# 31 58 1.0
# 32 2 1.0
# 33 244 1.0
# 34 41 1.0
# 35 217 1.0
# 36 95 1.0
# 37 141 1.0
# 38 195 1.0
# 39 39 1.0
# 40 197 1.0
# 41 59 1.0
# 42 150 1.0
# 43 108 1.0
# 44 14 1.0
# 45 131 1.0
# 46 273 1.0
# 47 288 1.0
# 48 287 1.0
# 49 84 1.0
# 50 228 1.0
# 51 294 1.0
# 52 151 1.0
# 53 98 1.0
# 54 267 1.0
# 55 49 1.0
# 56 61 1.0
# 57 86 1.0
# 58 271 1.0
# 59 196 1.0
# 60 265 1.0
# 61 129 1.0
# 62 8 1.0
# 63 208 1.0
# 64 297 1.0
# 65 113 1.0
# 66 112 1.0
# 67 111 1.0
# 68 260 1.0
# 69 99 1.0
# 70 145 1.0
# 71 198 1.0
# 72 187 1.0
# 73 92 1.0
# 74 214 1.0
# 75 38 1.0
# 76 245 1.0
# 77 57 1.0
# 78 144 1.0
# 79 185 1.0
# ...
